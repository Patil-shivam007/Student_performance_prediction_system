# %%
import pandas as pd

df = pd.read_excel(
    "college_student_performance_dataset.xlsx",
    sheet_name="Performance_Data"
)

features = [
    "age",
    "gender",
    "category",
    "semester",
    "subject",
    "attendance_percentage",
    "study_hours_per_day",
    "assignment_completion_percentage",
    "internal_marks",
    "midterm_marks",
    "previous_semester_sgpa"
]

X = df[features]
y = df["final_marks"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (30000, 11)
# y shape: (30000,)

# %%
# Numerical features
numerical_features = [
    "age",
    "semester",
    "attendance_percentage",
    "study_hours_per_day",
    "assignment_completion_percentage",
    "internal_marks",
    "midterm_marks",
    "previous_semester_sgpa"
]

# Categorical features
categorical_features = [
    "gender",
    "category",
    "subject"
]

print("Numerical features:")
print(numerical_features)

print("\nCategorical features:")
print(categorical_features)
# Out:
# Numerical features:
# ['age', 'semester', 'attendance_percentage', 'study_hours_per_day', 'assignment_completion_percentage', 'internal_marks', 'midterm_marks', 'previous_semester_sgpa']
#
# Categorical features:
# ['gender', 'category', 'subject']

# %%
math_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
#  20  higher      395 non-null    str
#  21  internet    395 non-null    str
#  22  romantic    395 non-null    str
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), str(17)
# memory usage: 102.0 KB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        (
            "categorical",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ],
    remainder="passthrough"
)

print("Preprocessor created successfully!")
# Out:
# Preprocessor created successfully!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (24000, 11)
# Testing data: (6000, 11)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

linear_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LinearRegression())
    ]
)

print("Linear Regression pipeline created!")
# Out:
# Linear Regression pipeline created!

# %%
linear_model.fit(X_train, y_train)

print("Linear Regression model trained successfully!")
# Out:
# Linear Regression model trained successfully!

# %%
y_pred = linear_model.predict(X_test)

print(y_pred[:10])
# Out:
# [36.83528151 29.32006835 40.45728977 43.38328396 43.4867214  30.28116508
#  31.44856671 32.9150327  54.01314691 40.01911709]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("R² Score:", r2)
# Out:
# MAE: 3.5630260981048063
# R² Score: 0.8301370503936184

# %%
X.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  goout  Dalc Walc health absences  G1  G2
# 0       no      4         3      4     1    1      3        6   5   6
# 1       no      5         3      3     1    1      3        4   5   5
# 2       no      4         3      2     2    3      3       10   7   8
# 3      yes      3         2      2     1    1      5        2  15  14
# 4       no      4         3      2     1    2      5        4   6  10
#
# [5 rows x 32 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline

decision_tree_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", DecisionTreeRegressor(
            random_state=42,
            max_depth=10
        ))
    ]
)

print("Decision Tree pipeline created!")
# Out:
# Decision Tree pipeline created!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
print("Training target:", y_train.shape)
print("Testing target:", y_test.shape)
# Out:
# Training data: (316, 32)
# Testing data: (79, 32)
# Training target: (316,)
# Testing target: (79,)

# %%
decision_tree_model.fit(X_train, y_train)

print("Decision Tree model trained successfully!")
# Out:
# Decision Tree model trained successfully!

# %%
y_pred_dt = decision_tree_model.predict(X_test)

print(y_pred_dt[:10])
# Out:
# [31.78422222 29.7492     39.25181818 44.36809524 41.82755906 29.7492
#  32.01694915 35.24877358 54.45       41.82755906]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_dt = mean_absolute_error(y_test, y_pred_dt)
r2_dt = r2_score(y_test, y_pred_dt)

print("Decision Tree MAE:", mae_dt)
print("Decision Tree R²:", r2_dt)
# Out:
# Decision Tree MAE: 3.7737526399958177
# Decision Tree R²: 0.8002227025962871

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline

decision_tree_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", DecisionTreeRegressor(
            random_state=42,
            max_depth=5
        ))
    ]
)

decision_tree_model.fit(X_train, y_train)

print("Decision Tree model trained successfully.")
# Out:
# Decision Tree model trained successfully.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

random_forest_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", RandomForestRegressor(
            n_estimators=100,
            max_depth=10,
            random_state=42,
            n_jobs=-1
        ))
    ]
)

print("Random Forest pipeline created!")
# Out:
# Random Forest pipeline created!

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

random_forest_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", RandomForestRegressor(
            n_estimators=200,
            random_state=42,
            max_depth=8
        ))
    ]
)

random_forest_model.fit(X_train, y_train)

print("Random Forest model trained successfully.")
# Out:
# Random Forest model trained successfully.

# %%
random_forest_model.fit(X_train, y_train)

print("Random Forest model trained successfully!")
# Out:
# Random Forest model trained successfully!

# %%
y_pred_rf = random_forest_model.predict(X_test)

print(y_pred_rf[:10])
# Out:
# [33.19052887 29.05558875 40.14408193 43.85705363 44.19365443 29.11571548
#  31.60547493 32.68704859 52.5692534  41.09039533]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest MAE:", mae_rf)
print("Random Forest R²:", r2_rf)
# Out:
# Random Forest MAE: 3.4847756233985954
# Random Forest R²: 0.83292481431134

# %%
print("===== MODEL COMPARISON =====")

print("Linear Regression")
print("MAE:", mae)
print("R²:", r2)

print("\nDecision Tree")
print("MAE:", mae_dt)
print("R²:", r2_dt)

print("\nRandom Forest")
print("MAE:", mae_rf)
print("R²:", r2_rf)
# Out:
# ===== MODEL COMPARISON =====
# Linear Regression
# MAE: 3.5630260981048063
# R²: 0.8301370503936184
#
# Decision Tree
# MAE: 3.7737526399958177
# R²: 0.8002227025962871
#
# Random Forest
# MAE: 3.4847756233985954
# R²: 0.83292481431134

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "MAE": [
        mae,
        mae_dt,
        mae_rf
    ],
    "R2": [
        r2,
        r2_dt,
        r2_rf
    ]
})

print(results)
# Out:
#                Model       MAE        R2
# 0  Linear Regression  3.563026  0.830137
# 1      Decision Tree  3.773753  0.800223
# 2      Random Forest  3.484776  0.832925

# %%
best_model_name = results.loc[results["R2"].idxmax(), "Model"]

print("Best Model:", best_model_name)
# Out:
# Best Model: Random Forest

# %%
import joblib

joblib.dump(
    random_forest_model,
    "student_performance_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
new_student = pd.DataFrame([{
    "age": 20,
    "gender": "Male",
    "category": "General",
    "semester": 5,
    "subject": "Mathematics",
    "attendance_percentage": 85,
    "study_hours_per_day": 4,
    "assignment_completion_percentage": 90,
    "internal_marks": 25,
    "midterm_marks": 70,
    "previous_semester_sgpa": 8.2
}])

# %%
prediction = random_forest_model.predict(new_student)

print("Predicted Final Marks:", prediction[0])
# Out:
# Predicted Final Marks: 65.89050006109969
